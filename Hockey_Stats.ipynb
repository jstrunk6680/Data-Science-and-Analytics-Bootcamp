# %%
# !git config --global user.name "jstrunk6680"
# !git config --global user.email "aikidoka73@gmail.com"
# !git config --global user.password "8!tanU@9"

# %%
token = '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'
username = 'jstrunk6680'
repo = 'Data-Science-and-Analytics-Bootcamp'

# %%
# !git clone https://{token}@github.com/{username}/{repo}
# Out:
# Cloning into 'Data-Science-and-Analytics-Bootcamp'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 13 (delta 2), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (13/13), done.

# %%
# %cd {repo}
# Out:
# /content/Data-Science-and-Analytics-Bootcamp

# %%
# %ls
# Out:
# README.md  sentiment_analysis.ipynb  yelp_labeled.txt

# %%
# !mv r"/content/drive/MyDrive/Colab Notebooks/Hockey_Stats.ipynb" /content/Data-Science-and-Analytics-Bootcamp
# Out:
# mv: cannot stat 'r/content/drive/MyDrive/Colab Notebooks/Hockey_Stats.ipynb': No such file or directory

# %%
import pygsheets
import requests
import numpy as np
import pandas as pd
import io
from bs4 import BeautifulSoup
import json
import re
#authorization
gc = pygsheets.authorize(service_file='creds.json')

# %%
my_headers = {
'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 ' + ' (KHTML, like Gecko) Chrome/61.0.3163.100Safari/537.36'
}
# DI women
d_i = 'https://json-b.uscho.com/json/stats/overall/division-i-women'
r = requests.get(url = d_i, headers = my_headers)
# DIII women
# d_iii = 'https://json-b.uscho.com/json/stats/overall/division-iii-women'
# r = requests.get(url = d_iii, headers = my_headers)
# print("request code: ", r.status_code)

# %%
html_response = r.text
# print(html_response)

# %%
data = json.loads(html_response)
# print("Datatype after deserialization : "
#       + str(type(data)))

# %%
df = pd.read_json(html_response)
# df.head()

# %%
#newdf = df.drop('meta_data',axis='columns')

# %%
newdf = pd.concat([newdf['json'].apply(pd.Series), newdf.drop('json', axis = 1)], axis = 1)
newdf.head()
# Out:
#                                                   data  \
# dt1  [[9, <a href="/stats/player/wid,14048/Chlo̩-A...
# dt2  [[22, <a href="/stats/player/wid,14048/Chlo̩-...
# dt3  [[12, <a href="/stats/player/wid,14048/Chlo̩-...
# dt4  [[2, <a href="/stats/player/wid,14048/Chlo̩-A...
# dt5  [[1, <a href="/stats/player/wid,14048/Chlo̩-A...
#
#                                              meta_data  \
# dt1  {'index': 1, 'format': 'datatable', 'paging': ...
# dt2  {'paging': 1, 'format': 'datatable', 'index': ...
# dt3  {'bFilter': 1, 'order': [['3', 'desc']], 'colu...
# dt4  {'columns': [{'title': 'Rk'}, {'title': 'Name'...
# dt5  {'index': 1, 'format': 'datatable', 'paging': ...
#
#                               datatable  \
# dt1    {'sub_title': 'Scoring Leaders'}
# dt2              {'sub_title': 'Goals'}
# dt3            {'sub_title': 'Assists'}
# dt4   {'sub_title': 'Power Play Goals'}
# dt5  {'sub_title': 'Shorthanded Goals'}
#
# ...

# %%
newdf = pd.concat([newdf['datatable'].apply(pd.Series), newdf.drop('datatable', axis = 1)], axis = 1)
newdf.head()
# Out:
#              sub_title                                               data  \
# dt1    Scoring Leaders  [[9, <a href="/stats/player/wid,14048/Chlo̩-A...
# dt2              Goals  [[22, <a href="/stats/player/wid,14048/Chlo̩-...
# dt3            Assists  [[12, <a href="/stats/player/wid,14048/Chlo̩-...
# dt4   Power Play Goals  [[2, <a href="/stats/player/wid,14048/Chlo̩-A...
# dt5  Shorthanded Goals  [[1, <a href="/stats/player/wid,14048/Chlo̩-A...
#
#                                              meta_data  \
# dt1  {'index': 1, 'format': 'datatable', 'paging': ...
# dt2  {'paging': 1, 'format': 'datatable', 'index': ...
# dt3  {'bFilter': 1, 'order': [['3', 'desc']], 'colu...
# dt4  {'columns': [{'title': 'Rk'}, {'title': 'Name'...
# dt5  {'index': 1, 'format': 'datatable', 'paging': ...
#
#                                             page_title gender division  \
# dt1  Women's Division I Overall_template Hockey Sta...      w        I
# ...

# %%
newdf = pd.concat([newdf['meta_data'].apply(pd.Series), newdf.drop('meta_data', axis = 1)], axis = 1)
newdf.head()
# Out:
#      index     format  paging  bInfo  \
# dt1      1  datatable       1      0
# dt2      1  datatable       1      0
# dt3      1  datatable       1      0
# dt4      1  datatable       1      0
# dt5      1  datatable       1      0
#
#                                                columns        order  bFilter  \
# dt1  [{'searchable': 0, 'title': 'Rk', 'orderable':...  [[5, desc]]        1
# dt2  [{'title': 'Rk'}, {'title': 'Name'}, {'title':...  [[3, desc]]        1
# dt3  [{'title': 'Rk'}, {'title': 'Name'}, {'title':...  [[3, desc]]        1
# dt4  [{'title': 'Rk'}, {'title': 'Name'}, {'title':...  [[3, desc]]        1
# dt5  [{'title': 'Rk'}, {'title': 'Name'}, {'title':...  [[3, desc]]        1
#
#              sub_title                                               data  \
# dt1    Scoring Leaders  [[9, <a href="/stats/player/wid,14048/Chlo̩-A...
# dt2              Goals  [[22, <a href="/stats/player/wid,14048/Chlo̩-...
# ...

# %%
newdf = pd.concat([newdf['columns'].apply(pd.Series), newdf.drop('columns', axis = 1)], axis = 1)
newdf.head()
# Out:
#                                                      0                  1  \
# dt1  {'searchable': 0, 'title': 'Rk', 'orderable': ...  {'title': 'Name'}
# dt2                                    {'title': 'Rk'}  {'title': 'Name'}
# dt3                                    {'title': 'Rk'}  {'title': 'Name'}
# dt4                                    {'title': 'Rk'}  {'title': 'Name'}
# dt5                                    {'title': 'Rk'}  {'title': 'Name'}
#
#                    2                 3               4                 5  \
# dt1  {'title': 'GP'}    {'title': 'G'}  {'title': 'A'}  {'title': 'Pts'}
# dt2  {'title': 'GP'}    {'title': 'G'}             NaN               NaN
# dt3  {'title': 'GP'}    {'title': 'A'}             NaN               NaN
# dt4  {'title': 'GP'}  {'title': 'PPG'}             NaN               NaN
# dt5  {'title': 'GP'}  {'title': 'SHG'}             NaN               NaN
#
#                        6                 7                 8  \
# ...

# %%
nnewdf = newdf.drop(['bInfo','index','order','format','paging','bFilter'],axis='columns')
nnewdf.head()
# nnewdf.to_csv('datatables.csv')
# Out:
#                                                      0                  1  \
# dt1  {'searchable': 0, 'title': 'Rk', 'orderable': ...  {'title': 'Name'}
# dt2                                    {'title': 'Rk'}  {'title': 'Name'}
# dt3                                    {'title': 'Rk'}  {'title': 'Name'}
# dt4                                    {'title': 'Rk'}  {'title': 'Name'}
# dt5                                    {'title': 'Rk'}  {'title': 'Name'}
#
#                    2                 3               4                 5  \
# dt1  {'title': 'GP'}    {'title': 'G'}  {'title': 'A'}  {'title': 'Pts'}
# dt2  {'title': 'GP'}    {'title': 'G'}             NaN               NaN
# dt3  {'title': 'GP'}    {'title': 'A'}             NaN               NaN
# dt4  {'title': 'GP'}  {'title': 'PPG'}             NaN               NaN
# dt5  {'title': 'GP'}  {'title': 'SHG'}             NaN               NaN
#
#                        6                 7                 8  \
# ...

# %%
dt1 = nnewdf.iloc[[0]]
dt2 = nnewdf.iloc[[1]]
dt3 = nnewdf.iloc[[2]]
dt4 = nnewdf.iloc[[3]]
dt5 = nnewdf.iloc[[4]]
dt6 = nnewdf.iloc[[5]]
dt7 = nnewdf.iloc[[6]]
dt8 = nnewdf.iloc[[7]]
dt9 = nnewdf.iloc[[8]]
dt10 = nnewdf.iloc[[9]]
dt11 = nnewdf.iloc[[10]]
dt12 = nnewdf.iloc[[11]]
dt13 = nnewdf.iloc[[12]]
dt14 = nnewdf.iloc[[13]]
dt15 = nnewdf.iloc[[14]]
dt1.head()
# Out:
#                                                      0                  1  \
# dt1  {'searchable': 0, 'title': 'Rk', 'orderable': ...  {'title': 'Name'}
#
#                    2               3               4                 5  \
# dt1  {'title': 'GP'}  {'title': 'G'}  {'title': 'A'}  {'title': 'Pts'}
#
#                        6                 7                 8  \
# dt1  {'title': 'Pts/GP'}  {'title': 'GWG'}  {'title': 'PPG'}
#
#                     9  ...   11   12   13   14        sub_title  \
# dt1  {'title': 'SHG'}  ...  NaN  NaN  NaN  NaN  Scoring Leaders
#
#                                                   data  \
# dt1  [[9, <a href="/stats/player/wid,14048/Chlo̩-A...
#
#                                             page_title gender division  \
# dt1  Women's Division I Overall_template Hockey Sta...      w        I
#
#     full_season
# dt1   2022-2023
#
# [1 rows x 21 columns]

# %%
dt1['data'].to_frame()
dt2['data'].to_frame()
dt3['data'].to_frame()
dt4['data'].to_frame()
dt5['data'].to_frame()
dt6['data'].to_frame()
dt7['data'].to_frame()
dt8['data'].to_frame()
dt9['data'].to_frame()
dt10['data'].to_frame()
dt11['data'].to_frame()
dt12['data'].to_frame()
dt13['data'].to_frame()
dt14['data'].to_frame()
dt15['data'].to_frame()
# Out:
#                                                    data
# dt15  [[1, <a href="/team/minnesota/womens-hockey/">...

# %%
dt1_1 = dt1['data'].apply(pd.Series)
# print(type(dt1_1))
dt2_1 = dt2['data'].apply(pd.Series)
dt3_1 = dt3['data'].apply(pd.Series)
dt4_1 = dt4['data'].apply(pd.Series)
dt5_1 = dt5['data'].apply(pd.Series)
dt6_1 = dt6['data'].apply(pd.Series)
dt7_1 = dt7['data'].apply(pd.Series)
dt8_1 = dt8['data'].apply(pd.Series)
dt9_1 = dt9['data'].apply(pd.Series)
dt10_1 = dt10['data'].apply(pd.Series)
dt11_1 = dt11['data'].apply(pd.Series)
dt12_1 = dt12['data'].apply(pd.Series)
dt13_1 = dt13['data'].apply(pd.Series)
dt14_1 = dt14['data'].apply(pd.Series)
dt15_1 = dt15['data'].apply(pd.Series)
dt1_1.head()
# Out:
#                                                   0     \
# dt1  [9, <a href="/stats/player/wid,14048/Chlo̩-Au...
#
#                                                   1     \
# dt1  [35, <a href="/stats/player/wid,21671/Alexis-P...
#
#                                                   2     \
# dt1  [213, <a href="/stats/player/wid,14163/Charlot...
#
#                                                   3     \
# dt1  [32, <a href="/stats/player/wid,21549/Tessa-Ja...
#
#                                                   4     \
# dt1  [341, <a href="/stats/player/wid,17151/Paige-L...
#
#                                                   5     \
# dt1  [1, <a href="/stats/player/wid,13988/Taylor-He...
#
#                                                   6     \
# dt1  [28, <a href="/stats/player/wid,15667/Abbey-Mu...
#
#                                                   7     \
# dt1  [247, <a href="/stats/player/wid,21674/Brianna...
#
# ...

# %%
dt1_stacked = dt1_1.stack().reset_index().rename(columns={'level_1': 'col1', 0: 'data'})
# print(type(dt1_stacked))
# print(dt1_stacked)
dt2_stacked = dt2_1.stack().reset_index().rename(columns={'level_1': 'col1', 0: 'data'})
dt3_stacked = dt3_1.stack().reset_index().rename(columns={'level_1': 'col1', 0: 'data'})
dt4_stacked = dt4_1.stack().reset_index().rename(columns={'level_1': 'col1', 0: 'data'})
dt5_stacked = dt5_1.stack().reset_index().rename(columns={'level_1': 'col1', 0: 'data'})
dt6_stacked = dt6_1.stack().reset_index().rename(columns={'level_1': 'col1', 0: 'data'})
dt7_stacked = dt7_1.stack().reset_index().rename(columns={'level_1': 'col1', 0: 'data'})
dt8_stacked = dt8_1.stack().reset_index().rename(columns={'level_1': 'col1', 0: 'data'})
dt9_stacked = dt9_1.stack().reset_index().rename(columns={'level_1': 'col1', 0: 'data'})
dt10_stacked = dt10_1.stack().reset_index().rename(columns={'level_1': 'col1', 0: 'data'})
dt11_stacked = dt11_1.stack().reset_index().rename(columns={'level_1': 'col1', 0: 'data'})
dt12_stacked = dt12_1.stack().reset_index().rename(columns={'level_1': 'col1', 0: 'data'})
dt13_stacked = dt13_1.stack().reset_index().rename(columns={'level_1': 'col1', 0: 'data'})
dt14_stacked = dt14_1.stack().reset_index().rename(columns={'level_1': 'col1', 0: 'data'})
dt15_stacked = dt15_1.stack().reset_index().rename(columns={'level_1': 'col1', 0: 'data'})

# %%
dt1_1_1 = dt1_stacked['data'].apply(pd.Series).rename(columns={0:'Rank',1:'Name',2:'Games Played',3:'Goals',4:'Assists',5:'Points',6:'Points/GP',7:'Game-winning Goals',8:'Power-play Goals',9:'Short-handed Goals'})
# print(type(dt1_1_1))
# dt1_1_1.head()
dt2_1_1 = dt2_stacked['data'].apply(pd.Series).rename(columns={0:'Rank',1:'Name',2:'Games Played',3:'Goals'})
dt3_1_1 = dt3_stacked['data'].apply(pd.Series).rename(columns={0:'Rank',1:'Name',2:'Games Played',3:'Assists'})
dt4_1_1 = dt4_stacked['data'].apply(pd.Series).rename(columns={0:'Rank',1:'Name',2:'Games Played',3:'Power-play Goals'})
dt5_1_1 = dt5_stacked['data'].apply(pd.Series).rename(columns={0:'Rank',1:'Name',2:'Games Played',3:'Short-handed Goals'})
dt6_1_1 = dt6_stacked['data'].apply(pd.Series).rename(columns={0:'Rank',1:'Name',2:'Games Played',3:'Wins',4:'Losses',5:'W%',6:'Min',7:'GA',8:'SV',9:'SV%',10:'GAA',11:'SHO'})
dt7_1_1 = dt7_stacked['data'].apply(pd.Series).rename(columns={0:'Rank',1:'Name',2:'Games Played',3:'SVP'})
dt8_1_1 = dt8_stacked['data'].apply(pd.Series).rename(columns={0:'Rank',1:'Name',2:'Games Played',3:'MIN'})
dt9_1_1 = dt9_stacked['data'].apply(pd.Series).rename(columns={0:'Rank',1:'Name',2:'Games Played',3:'SHO'})
dt10_1_1 = dt10_stacked['data'].apply(pd.Series).rename(columns={0:'Rank',1:'Team',2:'Games Played',3:'G',4:'GPG',5:'GAPG',6:'PPG',7:'PPO',8:'PP%',9:'PPGA',10:'PPGO',11:'PK%',10:'SHG',11:'SHGA'})
dt11_1_1 = dt11_stacked['data'].apply(pd.Series).rename(columns={0:'Rank',1:'Team',2:'Games Played',3:'G',4:'GPG',5:'GAPG',6:'PPG',7:'PPO',8:'PP%',9:'PPGA',10:'PPGO',11:'PK%',10:'SHG',11:'SHGA'})
dt12_1_1 = dt12_stacked['data'].apply(pd.Series).rename(columns={0:'Rank',1:'Team',2:'Games Played',3:'PPG/PPO',4:'PCT'})
dt13_1_1 = dt13_stacked['data'].apply(pd.Series).rename(columns={0:'Rank',1:'Team',2:'Games Played',3:'PPG/PPO',4:'PCT'})
dt14_1_1 = dt14_stacked['data'].apply(pd.Series).rename(columns={0:'Rank',1:'Team',2:'Games Played',3:'PEN/MIN',4:'AVG PCT'})
dt15_1_1 = dt15_stacked['data'].apply(pd.Series).rename(columns={0:'Rank',1:'Team',2:'Games Played',3:'TOT'})

# %%
dt1_1_1['Name_2'] = dt1_1_1.loc[:, 'Name']
dt2_1_1['Name_2'] = dt2_1_1.loc[:, 'Name']
dt3_1_1['Name_2'] = dt3_1_1.loc[:, 'Name']
dt4_1_1['Name_2'] = dt4_1_1.loc[:, 'Name']
dt5_1_1['Name_2'] = dt5_1_1.loc[:, 'Name']
dt6_1_1['Name_2'] = dt6_1_1.loc[:, 'Name']
dt7_1_1['Name_2'] = dt7_1_1.loc[:, 'Name']
dt8_1_1['Name_2'] = dt8_1_1.loc[:, 'Name']
dt9_1_1['Name_2'] = dt9_1_1.loc[:, 'Name']
dt10_1_1.head()
# Out:
#    Rank                                               Team  Games Played   G  \
# 0     2  <a href="/team/minnesota/womens-hockey/">Minne...            19  90
# 1     4  <a href="/team/northeastern/womens-hockey/">No...            21  84
# 2    22  <a href="/team/syracuse/womens-hockey/">Syracu...            21  49
# 3    15  <a href="/team/stonehill/womens-hockey/">Stone...            20  56
# 4    14  <a href="/team/mercyhurst/womens-hockey/">Merc...            18  54
#
#     GPG  GAPG   PPG  PPO  PP%   PPGA  SHG  SHGA     12  13 14
# 0  4.74    36  1.89   17   63  26.98    9    50  82.00   7  0
# 1  4.00    21  1.00   19   74  25.68    6    62  90.32   5  0
# 2  2.33    59  2.81   11   67  16.42    9    63  85.71   4  0
# 3  2.80    56  2.80    9   63  14.29    7    78  91.03   4  1
# 4  3.00    48  2.67    8   60  13.33   13    70  81.43   3  1

# %%
print(dt10_1_1.iloc[0]['Team'])
# Out:
# <a href="/team/minnesota/womens-hockey/">Minnesota</a>

# %%
dt1_1_1['Name_2'] = dt1_1_1['Name_2'].apply(lambda x:(re.findall(r"(Fr,.*|Sr,.*|Jr,.*|So,.*|Gr,.*)(?=,|)", str(x))))
# dt1_1_1.head()
dt2_1_1['Name_2'] = dt2_1_1['Name_2'].apply(lambda x:(re.findall(r"(Fr,.*|Sr,.*|Jr,.*|So,.*|Gr,.*)(?=,|)", str(x))))
dt3_1_1['Name_2'] = dt3_1_1['Name_2'].apply(lambda x:(re.findall(r"(Fr,.*|Sr,.*|Jr,.*|So,.*|Gr,.*)(?=,|)", str(x))))
dt4_1_1['Name_2'] = dt4_1_1['Name_2'].apply(lambda x:(re.findall(r"(Fr,.*|Sr,.*|Jr,.*|So,.*|Gr,.*)(?=,|)", str(x))))
dt5_1_1['Name_2'] = dt5_1_1['Name_2'].apply(lambda x:(re.findall(r"(Fr,.*|Sr,.*|Jr,.*|So,.*|Gr,.*)(?=,|)", str(x))))
dt6_1_1['Name_2'] = dt6_1_1['Name_2'].apply(lambda x:(re.findall(r"(Fr,.*|Sr,.*|Jr,.*|So,.*|Gr,.*)(?=,|)", str(x))))
dt7_1_1['Name_2'] = dt7_1_1['Name_2'].apply(lambda x:(re.findall(r"(Fr,.*|Sr,.*|Jr,.*|So,.*|Gr,.*)(?=,|)", str(x))))
dt8_1_1['Name_2'] = dt8_1_1['Name_2'].apply(lambda x:(re.findall(r"(Fr,.*|Sr,.*|Jr,.*|So,.*|Gr,.*)(?=,|)", str(x))))
dt9_1_1['Name_2'] = dt9_1_1['Name_2'].apply(lambda x:(re.findall(r"(Fr,.*|Sr,.*|Jr,.*|So,.*|Gr,.*)(?=,|)", str(x))))

# %%
dt9_1_1.head()
# Out:
#    Rank                                               Name  Games Played  SHO  \
# 0     1  <a href="/stats/player/wid,15786/Michelle-Pasi...            17    7
# 1     2  <a href="/stats/player/wid,21574/Sandra-Abstre...            22    6
# 2     3  <a href="/stats/player/wid,14844/Gwyneth-Phili...            21    5
# 3     3  <a href="/stats/player/wid,14084/Logan-Angers/...            13    5
# 4     5  <a href="/stats/player/wid,14017/Cami-Kronish/...            12    4
#
#          Name_2
# 0  [Jr, G, CLK]
# 1  [Sr, G, PRV]
# 2  [Sr, G, NOE]
# 3  [Sr, G, QUI]
# 4  [Sr, G, WIS]

# %%
def get_abs_url(html_tag):
  soup = BeautifulSoup(html_tag,'lxml')
  abs_url = 'https://www.uscho.com' + soup.find('a')['href']
  Name = soup.find('a').get_text()
  return abs_url, Name
dt1_1_1["abs_url"], dt1_1_1["Name"] = zip(*dt1_1_1["Name"].apply(get_abs_url))
dt2_1_1["abs_url"], dt2_1_1["Name"] = zip(*dt2_1_1["Name"].apply(get_abs_url))
dt3_1_1["abs_url"], dt3_1_1["Name"] = zip(*dt3_1_1["Name"].apply(get_abs_url))
dt4_1_1["abs_url"], dt4_1_1["Name"] = zip(*dt4_1_1["Name"].apply(get_abs_url))
dt5_1_1["abs_url"], dt5_1_1["Name"] = zip(*dt5_1_1["Name"].apply(get_abs_url))
dt6_1_1["abs_url"], dt6_1_1["Name"] = zip(*dt6_1_1["Name"].apply(get_abs_url))
dt7_1_1["abs_url"], dt7_1_1["Name"] = zip(*dt7_1_1["Name"].apply(get_abs_url))
dt8_1_1["abs_url"], dt8_1_1["Name"] = zip(*dt8_1_1["Name"].apply(get_abs_url))
dt9_1_1["abs_url"], dt9_1_1["Name"] = zip(*dt9_1_1["Name"].apply(get_abs_url))
dt10_1_1["abs_url"], dt10_1_1["Team"] = zip(*dt10_1_1["Team"].apply(get_abs_url))
dt11_1_1["abs_url"], dt11_1_1["Team"] = zip(*dt11_1_1["Team"].apply(get_abs_url))
dt12_1_1["abs_url"], dt12_1_1["Team"] = zip(*dt12_1_1["Team"].apply(get_abs_url))
dt13_1_1["abs_url"], dt13_1_1["Team"] = zip(*dt13_1_1["Team"].apply(get_abs_url))
dt14_1_1["abs_url"], dt14_1_1["Team"] = zip(*dt14_1_1["Team"].apply(get_abs_url))
dt15_1_1["abs_url"], dt15_1_1["Team"] = zip(*dt15_1_1["Team"].apply(get_abs_url))
dt10_1_1.head()
# Out:
#    Rank          Team  Games Played   G   GPG  GAPG   PPG  PPO  PP%   PPGA  \
# 0     2     Minnesota            19  90  4.74    36  1.89   17   63  26.98
# 1     4  Northeastern            21  84  4.00    21  1.00   19   74  25.68
# 2    22      Syracuse            21  49  2.33    59  2.81   11   67  16.42
# 3    15     Stonehill            20  56  2.80    56  2.80    9   63  14.29
# 4    14    Mercyhurst            18  54  3.00    48  2.67    8   60  13.33
#
#    SHG  SHGA     12  13 14                                            abs_url
# 0    9    50  82.00   7  0  https://www.uscho.com/team/minnesota/womens-ho...
# 1    6    62  90.32   5  0  https://www.uscho.com/team/northeastern/womens...
# 2    9    63  85.71   4  0  https://www.uscho.com/team/syracuse/womens-hoc...
# 3    7    78  91.03   4  1  https://www.uscho.com/team/stonehill/womens-ho...
# 4   13    70  81.43   3  1  https://www.uscho.com/team/mercyhurst/womens-h...

# %%
scoring_leaders = dt1_1_1.assign(division='DI',title='Scoring Leaders')
Goals = dt2_1_1.assign(division='DI',title='Goals')
Assists = dt3_1_1.assign(division='DI',title='Assists')
power_play_goals = dt4_1_1.assign(division='DI',title='Power Play Goals')
shorthanded_goals = dt5_1_1.assign(division='DI',title='Shorthanded Goals')
goaltending_leaders = dt6_1_1.assign(division='DI',title='Goaltending Leaders')
save_percentage = dt7_1_1.assign(division='DI',title='Save Percentage')
minutes_played = dt8_1_1.assign(division='DI',title='Minutes Played')
Shutouts = dt9_1_1.assign(division='DI',title='Shutouts')
team_offense = dt10_1_1.assign(division='DI',title='Team Offense')
team_defense = dt11_1_1.assign(division='DI',title='Team Defense')
power_play = dt12_1_1.assign(division='DI',title='Power Play')
penalty_kill = dt13_1_1.assign(division='DI',title='Penalty Kill')
penalty_minutes = dt14_1_1.assign(division='DI',title='Penalty Minutes')
shorthanded_goals = dt15_1_1.assign(division='DI',title='Shorthanded Goals')
scoring_leaders.head()
# Out:
#    Rank             Name  Games Played  Goals  Assists  Points Points/GP  \
# 0     9    Chlo̩ Aurard            21     11       17      28    1.3333
# 1    35   Alexis Petford            20     13        8      21    1.0500
# 2   213  Charlotte Welch            12      3        5       8    0.6667
# 3    32    Tessa Janecke            22     12       10      22    1.0000
# 4   341     Paige Lester            14      3        2       5    0.3571
#
#   Game-winning Goals  Power-play Goals  Short-handed Goals        Name_2  \
# 0                  3                 5                   2  [Sr, F, NOE]
# 1                  1                 1                   2  [Fr, F, STN]
# 2                  0                 0                   2  [Sr, F, YAL]
# 3                  2                 3                   2  [Fr, F, PSU]
# 4                  1                 0                   2  [So, F, HAR]
#
#                                              abs_url division            title
# ...

# %%
sh = gc.open('scoring_leaders')
wks = sh[0]
wks.set_dataframe(scoring_leaders,(1,1))

# %%
# scoring_leaders.to_csv('scoring_leaders_DI.csv')
# Goals.to_csv('goals_DI.csv')
# Assists.to_csv('assists_DI.csv')
# power_play_goals.to_csv('power_play_goals_DI.csv')
# shorthanded_goals.to_csv('shorthanded_goals_DI.csv')
# goaltending_leaders.to_csv('goaltending_leaders_DI.csv')
# save_percentage.to_csv('save_percentage_DI.csv')
# minutes_played.to_csv('minutes_played_DI.csv')
# Shutouts.to_csv('Shutouts_DI.csv')
# team_offense.to_csv('team_offense_DI.csv')
# team_defense.to_csv('team_defense_DI.csv')
# power_play.to_csv('power_play_DI.csv')
# penalty_kill.to_csv('penalty_kill_DI.csv')
# penalty_minutes.to_csv('penalty_minutes_DI.csv')
# shorthanded_goals.to_csv('shorthanded_goals_DI.csv')

# %%
# for index, row in nnewdf.iterrows():
#   # dt1 = nnewdf.iloc[[t]]
#   dt1 = nnewdf.iloc[: , [1, 2]].copy()
# # for index, row in df.iterrows():
# #   print(row["Name"], row["Age"])
